# %% [markdown]
# # Clasificador de imágenes

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.utils import np_utils
import os
import numpy as np
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Configuración de parámetros

# %%
width_shape = 224
height_shape = 224
num_classes = 2
epochs = 50
batch_size = 32

# %% [markdown]
# # Path de dataset

# %%
train_data_dir = 'dataset/train'  
validation_data_dir = 'dataset/valid'

# %% [markdown]
# # Generador de imágenes (entrenamiento y validación)

# %%
train_datagen = ImageDataGenerator(  
    rotation_range=20,
    zoom_range=[0.2,0.6],
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=preprocess_input)

valid_datagen = ImageDataGenerator(    
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(  
    train_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    #save_to_dir='',
    class_mode='categorical')

validation_generator = valid_datagen.flow_from_directory(  
    validation_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    #save_to_dir='',
    class_mode='categorical')
# Out:
# Found 10093 images belonging to 2 classes.
# Found 213 images belonging to 2 classes.

# %% [markdown]
# # Entrenamiento de modelo VGG16

# %%
nb_train_samples = 10093 
nb_validation_samples = 213

image_input = Input(shape=(width_shape, height_shape, 3))

model = VGG16(input_tensor=image_input, include_top=True,weights='imagenet')

last_layer = model.get_layer('fc2').output
out = Dense(num_classes, activation='softmax', name='output')(last_layer)
custom_vgg_model = Model(image_input, out)

for layer in custom_vgg_model.layers[:-1]:
	layer.trainable = False
    

custom_vgg_model.compile(loss='categorical_crossentropy',optimizer='adadelta',metrics=['accuracy'])

custom_vgg_model.summary()

model_history = custom_vgg_model.fit_generator(  
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    steps_per_epoch=nb_train_samples//batch_size,
    validation_steps=nb_validation_samples//batch_size)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# output (Dense)               (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 8,194
# Non-trainable params: 134,260,544
# _________________________________________________________________
# Epoch 1/50
# 315/315 [==============================] - 89s 282ms/step - loss: 0.1094 - accuracy: 0.9594 - val_loss: 0.3512 - val_accuracy: 0.8333
# Epoch 2/50
# 315/315 [==============================] - 92s 293ms/step - loss: 0.0897 - accuracy: 0.9695 - val_loss: 0.0842 - val_accuracy: 0.9227
# Epoch 3/50
# 315/315 [==============================] - 85s 270ms/step - loss: 0.0745 - accuracy: 0.9728 - val_loss: 0.1766 - val_accuracy: 0.8895
# Epoch 4/50
# 315/315 [==============================] - 84s 267ms/step - loss: 0.0731 - accuracy: 0.9726 - val_loss: 0.4134 - val_accuracy: 0.8895
# Epoch 5/50
# 315/315 [==============================] - 85s 271ms/step - loss: 0.0702 - accuracy: 0.9754 - val_loss: 0.2250 - val_accuracy: 0.8564
# Epoch 6/50
# 315/315 [==============================] - 85s 269ms/step - loss: 0.0697 - accuracy: 0.9760 - val_loss: 0.1270 - val_accuracy: 0.9227
# Epoch 7/50
# 315/315 [==============================] - 89s 283ms/step - loss: 0.0693 - accuracy: 0.9759 - val_loss: 0.3072 - val_accuracy: 0.8785
# Epoch 8/50
# 315/315 [==============================] - 89s 284ms/step - loss: 0.0639 - accuracy: 0.9773 - val_loss: 1.5460 - val_accuracy: 0.8229
# Epoch 9/50
# 315/315 [==============================] - 88s 281ms/step - loss: 0.0612 - accuracy: 0.9779 - val_loss: 0.7188 - val_accuracy: 0.8564
# Epoch 10/50
# 315/315 [==============================] - 86s 272ms/step - loss: 0.0646 - accuracy: 0.9778 - val_loss: 0.4822 - val_accuracy: 0.9061
# Epoch 11/50
# 315/315 [==============================] - 86s 272ms/step - loss: 0.0613 - accuracy: 0.9798 - val_loss: 0.3935 - val_accuracy: 0.9006
# Epoch 12/50
# 315/315 [==============================] - 85s 271ms/step - loss: 0.0625 - accuracy: 0.9775 - val_loss: 0.4654 - val_accuracy: 0.8287
# Epoch 13/50
# 315/315 [==============================] - 86s 273ms/step - loss: 0.0587 - accuracy: 0.9789 - val_loss: 0.6247 - val_accuracy: 0.8564
# Epoch 14/50
# 315/315 [==============================] - 85s 271ms/step - loss: 0.0609 - accuracy: 0.9776 - val_loss: 0.3646 - val_accuracy: 0.8453
# Epoch 15/50
# 315/315 [==============================] - 85s 271ms/step - loss: 0.0610 - accuracy: 0.9800 - val_loss: 0.6379 - val_accuracy: 0.8385
# Epoch 16/50
# 315/315 [==============================] - 87s 275ms/step - loss: 0.0540 - accuracy: 0.9806 - val_loss: 1.2784 - val_accuracy: 0.8066
# Epoch 17/50
# 315/315 [==============================] - 84s 268ms/step - loss: 0.0574 - accuracy: 0.9787 - val_loss: 0.6217 - val_accuracy: 0.8508
# Epoch 18/50
# 315/315 [==============================] - 84s 265ms/step - loss: 0.0566 - accuracy: 0.9807 - val_loss: 0.1742 - val_accuracy: 0.8564
# Epoch 19/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0587 - accuracy: 0.9792 - val_loss: 0.3424 - val_accuracy: 0.8785
# Epoch 20/50
# 315/315 [==============================] - 86s 273ms/step - loss: 0.0585 - accuracy: 0.9808 - val_loss: 1.0921 - val_accuracy: 0.7514
# Epoch 21/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.5252 - val_accuracy: 0.8287
# Epoch 22/50
# 315/315 [==============================] - 83s 262ms/step - loss: 0.0552 - accuracy: 0.9816 - val_loss: 0.3305 - val_accuracy: 0.8854
# Epoch 23/50
# 315/315 [==============================] - 83s 264ms/step - loss: 0.0552 - accuracy: 0.9818 - val_loss: 0.2036 - val_accuracy: 0.9061
# Epoch 24/50
# 315/315 [==============================] - 83s 264ms/step - loss: 0.0584 - accuracy: 0.9800 - val_loss: 1.0564 - val_accuracy: 0.8564
# Epoch 25/50
# 315/315 [==============================] - 83s 262ms/step - loss: 0.0480 - accuracy: 0.9826 - val_loss: 0.0790 - val_accuracy: 0.8785
# Epoch 26/50
# 315/315 [==============================] - 83s 262ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.6260 - val_accuracy: 0.8343
# Epoch 27/50
# 315/315 [==============================] - 82s 261ms/step - loss: 0.0540 - accuracy: 0.9824 - val_loss: 0.2495 - val_accuracy: 0.9227
# Epoch 28/50
# 315/315 [==============================] - 82s 261ms/step - loss: 0.0565 - accuracy: 0.9798 - val_loss: 0.7403 - val_accuracy: 0.8564
# Epoch 29/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0543 - accuracy: 0.9807 - val_loss: 1.9932 - val_accuracy: 0.8073
# Epoch 30/50
# 315/315 [==============================] - 83s 262ms/step - loss: 0.0544 - accuracy: 0.9815 - val_loss: 1.2030 - val_accuracy: 0.8453
# Epoch 31/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0546 - accuracy: 0.9824 - val_loss: 0.9185 - val_accuracy: 0.8674
# Epoch 32/50
# 315/315 [==============================] - 82s 260ms/step - loss: 0.0514 - accuracy: 0.9809 - val_loss: 0.6460 - val_accuracy: 0.8674
# Epoch 33/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0544 - accuracy: 0.9821 - val_loss: 0.9514 - val_accuracy: 0.8453
# Epoch 34/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0572 - accuracy: 0.9803 - val_loss: 0.5727 - val_accuracy: 0.8729
# Epoch 35/50
# 315/315 [==============================] - 82s 259ms/step - loss: 0.0488 - accuracy: 0.9833 - val_loss: 1.7678 - val_accuracy: 0.8177
# Epoch 36/50
# 315/315 [==============================] - 82s 261ms/step - loss: 0.0531 - accuracy: 0.9811 - val_loss: 0.4178 - val_accuracy: 0.8646
# Epoch 37/50
# 315/315 [==============================] - 83s 264ms/step - loss: 0.0548 - accuracy: 0.9820 - val_loss: 0.6300 - val_accuracy: 0.8674
# Epoch 38/50
# 315/315 [==============================] - 84s 266ms/step - loss: 0.0534 - accuracy: 0.9826 - val_loss: 0.5979 - val_accuracy: 0.9337
# Epoch 39/50
# 315/315 [==============================] - 84s 266ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 0.9449 - val_accuracy: 0.8398
# Epoch 40/50
# 315/315 [==============================] - 84s 266ms/step - loss: 0.0526 - accuracy: 0.9812 - val_loss: 0.2637 - val_accuracy: 0.8840
# Epoch 41/50
# 315/315 [==============================] - 83s 264ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 0.5694 - val_accuracy: 0.8729
# Epoch 42/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0461 - accuracy: 0.9842 - val_loss: 0.0338 - val_accuracy: 0.8840
# Epoch 43/50
# 315/315 [==============================] - 83s 265ms/step - loss: 0.0478 - accuracy: 0.9836 - val_loss: 0.9412 - val_accuracy: 0.8594
# Epoch 44/50
# 315/315 [==============================] - 84s 265ms/step - loss: 0.0518 - accuracy: 0.9815 - val_loss: 1.3312 - val_accuracy: 0.8232
# Epoch 45/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0554 - accuracy: 0.9818 - val_loss: 0.1586 - val_accuracy: 0.9282
# Epoch 46/50
# 315/315 [==============================] - 84s 265ms/step - loss: 0.0512 - accuracy: 0.9823 - val_loss: 0.7163 - val_accuracy: 0.8122
# Epoch 47/50
# 315/315 [==============================] - 83s 264ms/step - loss: 0.0444 - accuracy: 0.9851 - val_loss: 1.2833 - val_accuracy: 0.8398
# Epoch 48/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 0.7994 - val_accuracy: 0.8453
# Epoch 49/50
# 315/315 [==============================] - 83s 263ms/step - loss: 0.0437 - accuracy: 0.9848 - val_loss: 0.5882 - val_accuracy: 0.8619
# Epoch 50/50
# 315/315 [==============================] - 84s 266ms/step - loss: 0.0547 - accuracy: 0.9835 - val_loss: 1.2132 - val_accuracy: 0.8281

# %% [markdown]
# # Grabar modelo en disco

# %%
custom_vgg_model.save("models/model_VGG16final.h5")

# %% [markdown]
# # Gráficas de entrenamiento y validación (accuracy - loss)

# %%
def plotTraining(hist, epochs, typeData):
    
    if typeData=="loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'-r',label='Loss Training')
    if typeData=="accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'-r',label='Accuracy Training')
    if typeData=="val_loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['val_loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'--b',label='Loss Validate')
    if typeData=="val_accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['val_accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'--b',label='Training Validate')
        

    plt.rc('xtick',labelsize=24)
    plt.rc('ytick',labelsize=24)
    plt.rc('legend', fontsize=18) 
    plt.legend()
    plt.xlabel('Number of Epochs',fontsize=24)
    plt.grid(True)

# %%
plotTraining(model_history,epochs,"loss")
plotTraining(model_history,epochs,"accuracy")
plotTraining(model_history,epochs,"val_loss")
plotTraining(model_history,epochs,"val_accuracy")

# %%
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.models import load_model

names = ['GRIETA','FISURA']

modelt = load_model("models/model_VGG16final.h5")
#modelt = custom_vgg_model

imaget_path = "‪ImagenPrueba.jpg"
imaget=cv2.resize(cv2.imread(imaget_path), (width_shape, height_shape), interpolation = cv2.INTER_AREA)
xt = np.asarray(imaget)
xt=preprocess_input(xt)
xt = np.expand_dims(xt,axis=0)
preds = modelt.predict(xt)

print(names[np.argmax(preds)])
plt.imshow(cv2.cvtColor(np.asarray(imaget),cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-2799dd9c91f7> in <module>
#       8
#       9 imaget_path = "‪ImagenPrueba.jpg"
# ---> 10 imaget=cv2.resize(cv2.imread(imaget_path), (width_shape, height_shape), interpolation = cv2.INTER_AREA)
#      11 xt = np.asarray(imaget)
#      12 xt=preprocess_input(xt)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
